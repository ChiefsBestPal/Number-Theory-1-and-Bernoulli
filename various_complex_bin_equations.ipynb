# %%
# %%latex
# ${"""PascalBernouilliTests \res = N(sym.solve(sum(temp),(x))[0])"""}$
# $element\:of \; row\: n \;and\; col\: k = \sum^{k}_{i=0}\binom{n}{i} \;\; ; n\:\epsilon \: \mathbb{N} \; ;k\: \epsilon \{0,n\}\\
# if\: k\:<\:n\;\; ; B_{row,col} = B_{row-1,col} +B_{row-1,col-1}\\
# if \: Max(k) B_{row,col} = 2\, B_{row-1,col-1}$
# Out:
# ${"""PascalBernouilliTests \res = N(sym.solve(sum(temp),(x))[0])"""}$
# $element\:of \; row\: n \;and\; col\: k = \sum^{k}_{i=0}\binom{n}{i} \;\; ; n\:\epsilon \: \mathbb{N} \; ;k\: \epsilon \{0,n\}\\
# if\: k\:<\:n\;\; ; B_{row,col} = B_{row-1,col} +B_{row-1,col-1}\\
# if \: Max(k) B_{row,col} = 2\, B_{row-1,col-1}$

# %%
# %%latex
# $\frac{n!}{k!(n - k)!} => \frac{n(n - 1)\dots(n - k + 1)}{k(k-1)\dots(1)} =>
#     \prod_{i = 1}^{k}\frac{(n + 1) - i}{i}$
# Out:
# $\frac{n!}{k! (n - k) !} => \frac{n(n - 1)\dots(n - k + 1)}{k(k-1)\dots(1)} =>
#     \prod_{i = 1}^{k}\frac{n + 1 - i}{i}$

# %%
# %%latex
#     symmetry: $C_n^k = C_n^{(n - k)},$ the calculated res here can
#     go up to $\min(n - k,k).$
# Out:
#     symmetry: $C_n^k = C_n^{(n - k)},$ the calculated res here can
#     go up to $\min(n - k,k).$

# %%
print("from WolframAlpha, with gamma function simmetry ! (try in future)")
from IPython.display import Image
Image("BinomialWithGammaWolfram.png")
#!["Visuals and results from Binomial Coefficient (May be useful for efficiently calculating larger numbers)"](BinomialWithGammaWolfram.png "To implement sometime")
# Out:
# from WolframAlpha, with gamma function simmetry ! (try in future)

# %%
from IPython.display import IFrame

print("Also for larger calculations; approximation of integral then Bk in Maclaurin formula","\r\n") 
IFrame(src="https://en.wikipedia.org/wiki/Stirling\'s_approximation", width=700, height=600)
# Out:
# Also for larger calculations:
#         <iframe
#             width="700"
#             height="600"
#             src="https://en.wikipedia.org/wiki/Stirling's_approximation"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
from MatplotlibBernouilliAnalysis.py import *
ax.set_yscale('function', functions=(exp, log))
ax.set(xlim=(0.42,14.0771525), ylim=(0.0757575757575758,5.31870446941632e+1769))
ax.set_yticks([0.0757575757575758,2.83822495706962e+78,1.98382953521301e+735,5.31870446941632e+1769])

plt.show()
matplotlib.pyplot.scatter(x,y)
matplotlib.pyplot.show()
# Out:
# seconds <____> for this test
# [0.4210303, 0.456654, 0.42810430000000005, 0.4412566, 0.4239719, 0.9971545, 1.02998, 0.9928838, 1.0149545, 1.0077063, 4.7344481, 4.765309800000001, 4.6504608, 4.618301600000001, 4.5989108, 14.0571053, 13.9828119, 13.9919299, 13.89999, 14.0771525] [0.0757575757575758, 0.0757575757575758, 0.0757575757575758, 0.0757575757575758, 0.0757575757575758, 2.83822495706962e+78, 2.83822495706962e+78, 2.83822495706962e+78, 2.83822495706962e+78, 2.83822495706962e+78, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf]
# [ 0.4         0.54747475  0.69494949  0.84242424  0.98989899  1.13737374
#   1.28484848  1.43232323  1.57979798  1.72727273  1.87474747  2.02222222
#   2.16969697  2.31717172  2.46464646  2.61212121  2.75959596  2.90707071
#   3.05454545  3.2020202   3.34949495  3.4969697   3.64444444  3.79191919
#   3.93939394  4.08686869  4.23434343  4.38181818  4.52929293  4.67676768
#   4.82424242  4.97171717  5.11919192  5.26666667  5.41414141  5.56161616
# ...

# %%
from IPython.display import Image
Image("HandCalc.jpg")
